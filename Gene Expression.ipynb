# %% [markdown]
# # Libraries

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
# ANOVA feature selection for numeric input and categorical output
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

import xgboost as xgb

# %%
key = 50

# %% [markdown]
# # Alopecia areata

# %%
df = pd.read_csv('Alopecia areata/Transform_Data.csv')

# %%
df.shape
# Out:
# (129, 30148)

# %%
df.isna().sum().sum()
# Out:
# 22

# %%
df.dropna(inplace =True)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Diagnosis'] = 0

# %%
df.info
# Out:
# <bound method DataFrame.info of      1007_s_at   1053_at    117_at    121_at   1294_at   1316_at   1320_at  \
# 0     3.415008  3.019226  2.571248  1.476333  2.985626  2.660889  1.981937
# 1     3.470063  3.000241  2.214963  1.435923  2.699710  2.671289  1.946117
# 2     3.468073  3.019885  2.142353  1.423358  2.748724  2.726195  2.009763
# 3     3.500024  3.059693  2.463672  1.340710  2.634279  2.505245  1.776441
# 5     3.501173  2.999537  2.764004  1.732539  2.878685  2.601433  1.825223
# ..         ...       ...       ...       ...       ...       ...       ...
# 124   3.480582  2.993795  2.291321  1.407116  2.828413  2.529908  1.835861
# 125   3.522482  3.099158  2.205759  1.415535  2.859465  2.480688  1.823639
# 126   3.464283  2.940836  2.388503  1.535569  3.094470  2.730789  2.001295
# 127   3.524695  3.033337  2.446718  1.538893  2.736635  2.577597  1.914909
# 128   3.489267  3.046574  2.626881  1.411260  2.893194  2.850015  2.123745
#
# ...

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)
# (120, 50)

# %%
Alopecia= pd.DataFrame(X_selected)

# %%
Alopecia['Dignosis'] = 0

# %%
Alopecia.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  2.432845  2.565060  2.886369  3.244528  2.467016  1.582711  2.998176
# 1  2.004851  2.648215  2.661599  3.188180  2.633036  1.917537  2.993436
# 2  1.879252  2.593174  2.675330  3.212804  2.628689  2.308124  3.015798
# 3  2.129046  2.781379  2.550756  3.215073  2.643258  2.231118  3.028180
# 4  2.021205  2.557857  2.650562  3.278612  2.550271  1.884823  2.960851
#
#           7         8         9  ...        41        42        43        44  \
# 0  2.929280  2.131583  1.696642  ...  3.346070  3.366568  3.359611  3.567706
# 1  2.789070  2.077612  1.699107  ...  3.322157  3.339700  3.331661  3.553438
# 2  2.783443  2.073225  1.819131  ...  3.328755  3.349446  3.335666  3.560275
# 3  2.925232  2.060499  1.920601  ...  3.322423  3.336001  3.347066  3.564931
# 4  2.889133  2.092515  1.980153  ...  3.267648  3.256089  3.262738  3.511002
#
#          45        46        47        48        49  Dignosis
# ...

# %%
Alopecia.to_csv('Alopecia areata/Feature.csv', index=False)

# %% [markdown]
# # Atopic Dermatitis

# %%
df1 = pd.read_csv('Atopic Dermatitis/Transform_Data.csv')

# %%
df.shape
# Out:
# (48, 47324)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1['Dignosis'] = 1
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
df.info
# Out:
# <bound method DataFrame.info of     ILMN_1343291  ILMN_1343295  ILMN_1651199  ILMN_1651209  ILMN_1651210  \
# 0      15.004413     13.433784      7.073491      7.150547      7.340642
# 1      14.842385     13.252002      6.811195      7.007074      6.943038
# 2      14.965791     13.457416      7.228625      7.174617      7.269446
# 3      14.879489     13.800142      7.407714      7.191310      7.149184
# 4      14.691028     13.641732      6.950535      6.941273      7.085326
# 5      14.729835     13.792669      6.903423      7.298597      7.010348
# 6      14.706143     13.463724      7.082309      7.197908      6.948207
# 7      14.753218     13.488741      7.040206      7.015631      7.231286
# 8      14.614950     13.540628      7.039829      7.082852      6.980899
# 9      14.863081     13.640497      6.835006      7.030768      6.957446
# 10     14.758047     13.412297      6.988327      6.802798      6.906784
# ...

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)
# (48, 50)

# %%
Atopic = pd.DataFrame(X_selected)

# %%
Atopic['Dignosis'] = 1

# %%
Atopic.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  6.958419  7.617961  7.173314  6.972295  7.226457  7.046727  7.269045
# 1  7.069350  7.079882  7.047339  7.042976  6.825027  6.936843  6.894224
# 2  6.925996  7.367949  7.214156  7.049357  7.103763  6.954131  6.880449
# 3  6.989065  7.160346  7.127582  6.946311  7.206542  6.954643  6.931235
# 4  7.022106  7.106887  7.117116  7.005913  6.863444  7.002185  6.879474
#
#           7         8         9  ...        41        42        43        44  \
# 0  7.214187  7.133260  7.019942  ...  7.171770  7.430517  7.024274  7.363935
# 1  7.089007  6.751174  6.850587  ...  6.802803  6.993293  7.089575  7.235652
# 2  7.252494  6.977439  7.157371  ...  6.934968  7.211901  7.106376  7.616163
# 3  7.410769  7.314880  7.079403  ...  7.055701  7.052500  7.052752  7.394160
# 4  7.383976  6.974634  6.769477  ...  7.133091  7.239477  7.048088  7.208683
#
#          45        46        47        48        49  Dignosis
# ...

# %%
Atopic.to_csv('Atopic Dermatitis/Feature.csv', index=False)

# %%
print(Atopic.shape)
print(Alopecia.shape)
# Out:
# (48, 51)
# (120, 51)

# %%
gene = pd.concat([Alopecia, Atopic])

# %% [markdown]
# # Behcet's Disease

# %%
df = pd.read_csv("Behcet's Disease/Transform_Data.csv")

# %%
df.shape
# Out:
# (34, 557)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Dignosis'] = 2
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
df.info
# Out:
# <bound method DataFrame.info of     DarkCorner   dmr_285     dmr_3    dmr_308   dmr_316   dmr_31a     dmr_6  \
# 0     8.567302  8.558241  8.634091   8.628852  8.604553  8.553053  8.500289
# 1     8.883932  8.863587  8.637108   8.684164  8.930876  8.897597  8.553573
# 2     7.249960  7.025608  6.965609   7.010179  7.038919  7.168691  7.000545
# 3     7.150685  6.909143  6.904855   6.943073  6.985308  6.957245  6.940810
# 4     7.901353  7.778128  8.058033   8.106754  7.898413  7.857981  7.788213
# 5     6.905199  6.800293  6.914433   6.874405  6.837102  6.920566  6.802392
# 6     7.074712  6.928447  6.969975   6.991092  6.997843  6.995659  7.046005
# 7     7.007553  6.955564  7.042375   7.077150  7.051590  7.037314  6.843725
# 8     6.902941  6.820376  6.932919   6.868176  6.884934  6.833305  6.884810
# 9     7.075829  6.915925  7.031403   7.004465  6.938039  6.989717  6.832112
# 10    7.110472  6.959378  7.006168   6.994353  7.000174  7.090069  6.915879
# ...

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# (34, 50)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)

# %%
Behcet = pd.DataFrame(X_selected)
Behcet['Dignosis'] = 2
Behcet.head()
# Out:
#            0         1         2          3         4          5         6  \
# 0   8.689773  8.670656  8.620656   8.542283  8.583688   8.558780  8.549464
# 1   8.691663  8.823923  8.849601   8.727704  8.854720   8.769476  8.666057
# 2   7.018728  7.002599  7.038404   7.013356  7.196085   6.942882  6.958806
# 3   7.030323  6.994789  7.078151   7.019975  7.005795   7.031324  6.940529
# 4  12.274146  7.766351  7.876517  12.375437  8.033694  13.414705  8.058516
#
#            7         8          9  ...         41        42         43  \
# 0   8.627113  8.689499   8.495855  ...   8.555484  8.578962   8.518776
# 1   8.727389  8.642489   8.770515  ...   8.742557  8.623767   8.724230
# 2   6.964501  6.959910   6.977638  ...   7.056857  6.977944   7.067477
# 3   7.029521  6.948097   7.084808  ...   6.968754  6.905595   7.010718
# 4  12.672041  8.090857  12.857619  ...  12.370659  7.903240  13.006051
#
#           44        45         46        47        48        49  Dignosis
# ...

# %%
Behcet.to_csv("Behcet's Disease/Feature.csv", index=False)

# %%
Behcet.shape
# Out:
# (34, 51)

# %%
gene = pd.concat([gene, Behcet])

# %%
gene['Dignosis'].value_counts()
# Out:
# 0    120
# 1     48
# 2     34
# Name: Dignosis, dtype: int64

# %% [markdown]
# # Bullous pemphigoid

# %%
df = pd.read_csv("Bullous pemphigoid/Transform_Data.csv")

# %%
print(df.isna().sum().sum())
print(df.duplicated().sum())
# Out:
# 69401
# 0

# %%
df.dropna(inplace=True, axis = 1)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (8, 12147)

# %%
df['Dignosis'] = 3
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# (8, 50)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)

# %%
Bullous = pd.DataFrame(X_selected)
Bullous['Dignosis'] = 3
Bullous.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.268815 -5.150639 -0.822490 -0.422174  0.102764  0.402252 -0.532527
# 1  0.176345 -3.916075 -0.588298 -0.325092 -0.001995  0.222125 -0.567736
# 2  0.464979 -3.612069 -0.602820 -0.611960 -0.103966  0.252873 -0.550639
# 3  0.405884 -5.019823 -0.578362 -0.052626  0.091912  0.410069 -0.493370
# 4  0.551462 -3.788970 -0.695522 -0.104941  0.177070  0.455956 -0.401550
#
#           7         8         9  ...        41        42        43        44  \
# 0 -0.245709  0.772642  0.393290  ... -1.366497  0.687292 -1.114966  1.714886
# 1 -0.015062  0.731633  0.423135  ... -1.314926  0.557456 -1.578858  1.661312
# 2 -0.159931  0.714793  0.368425  ... -1.379665  0.580309 -1.539484  1.634884
# 3 -0.050721  0.742319  0.400705  ... -1.418699  0.598500 -1.314452  1.669586
# 4 -0.169475  0.724474  0.499303  ... -1.409337  0.585067 -0.916879  1.654481
#
#          45        46        47        48        49  Dignosis
# ...

# %%
Bullous.to_csv("Bullous pemphigoid/Feature.csv", index=False)

# %%
gene = pd.concat([gene, Bullous])
gene['Dignosis'].value_counts()
# Out:
# 0    120
# 2     68
# 1     48
# 3      8
# Name: Dignosis, dtype: int64

# %% [markdown]
# # Dermatomyositis

# %%
df = pd.read_csv("Dermatomyositis/Transform_Data.csv")

# %%
print(df.isna().sum().sum())
print(df.duplicated().sum())
# Out:
# 0
# 0

# %%
df['Dignosis'] = 4
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)
# (48, 50)

# %%
Dermatomyositis = pd.DataFrame(X_selected)
Dermatomyositis['Dignosis'] = 4
Dermatomyositis.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  2.985876  3.164385  3.279410  3.056744  3.259320  0.680375  1.065840
# 1  2.961029  3.193531  3.283446  3.027110  3.242500  0.724334  1.018400
# 2  3.443948  3.510498  3.559061  3.470995  3.540407  1.288540  1.149986
# 3  2.988988  3.225729  3.225412  2.900056  3.157956  1.216728  0.874600
# 4  2.949506  3.187913  3.281669  2.953145  3.196305  1.077148  0.966854
#
#           7         8         9  ...        41        42        43        44  \
# 0  1.005751  3.412412  3.352913  ...  2.299989  3.613858  2.464573  3.631449
# 1  1.062634  3.460106  3.428627  ...  2.106555  3.622858  2.428874  3.629654
# 2  1.312507  3.624772  3.585450  ...  2.429914  3.633332  2.613499  3.647161
# 3  0.859960  3.442082  3.404820  ...  2.295575  3.596104  2.420730  3.612724
# 4  0.832569  3.431790  3.408298  ...  2.311507  3.583764  2.380861  3.577576
#
#          45        46        47        48        49  Dignosis
# ...

# %%
Dermatomyositis.to_csv("Dermatomyositis/Feature.csv", index=False)

# %%
gene = pd.concat([gene, Dermatomyositis])
gene['Dignosis'].value_counts()
# Out:
# 0    120
# 2     68
# 1     48
# 4     48
# 3      8
# Name: Dignosis, dtype: int64

# %% [markdown]
# # Epidermolysis bullosa

# %%
df = pd.read_csv("Epidermolysis bullosa/Transform_Data.csv")

# %%
print(df.isna().sum().sum())
print(df.duplicated().sum())
# Out:
# 1
# 0

# %%
df.dropna(inplace =True)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['Dignosis'] = 5
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# (19, 50)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)

# %%
Epidermolysis = pd.DataFrame(X_selected)
Epidermolysis['Dignosis'] = 5
Epidermolysis.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  2.945971  1.165078  1.478661  1.159845  1.370141  2.845464  1.649881
# 1  2.898439  1.200745  0.783940  0.588336  1.222728  2.811511  1.536406
# 2  2.861008  1.001162  1.273298  0.846349  0.864304  2.810302  1.534593
# 3  2.945491  0.570459  1.234228  0.645431  0.992941  2.838618  1.257668
# 4  2.814308  1.250365  1.936555  1.383072  0.759389  2.702357  1.200411
#
#           7         8         9  ...        41        42        43        44  \
# 0  0.748681  1.495599  1.509091  ...  1.210510  3.322899  1.849812  3.061726
# 1  1.112126  0.793771  1.166583  ...  1.159035  3.262236  1.700029  3.031893
# 2  0.938240  0.679497  1.242072  ...  1.557110  3.332282  1.475157  3.103089
# 3  1.435682  0.941797  1.220084  ...  1.353551  3.297754  1.182572  2.984941
# 4  1.373948  0.677286  0.941145  ...  1.429832  3.268335  1.626061  3.036119
#
#          45        46        47        48        49  Dignosis
# ...

# %%
Epidermolysis.to_csv("Epidermolysis bullosa/Feature.csv", index=False)

# %%
gene = pd.concat([gene, Epidermolysis])
gene['Dignosis'].value_counts()
# Out:
# 0    120
# 2     68
# 5     57
# 1     48
# 4     48
# 3      8
# Name: Dignosis, dtype: int64

# %% [markdown]
# # IGA Dermatosis

# %%
df = pd.read_csv("IGA Dermatosis/Transform_Data.csv")
# Out:
# C:\Users\laptop\AppData\Local\Temp/ipykernel_4624/2142763934.py:1: DtypeWarning: Columns (0,13,18,19,20,23,33,35,38,41,46,52,55,61,64,66,72,73,76,80,84,91,95,100,104,114,120,123,127,129,130,131,135,145,152,159,163,166,168,173,175,179,184,185,192,197,199,200,203,208,211,213,215,218,221,223,225,227,229,232,234,241,242,247,249,263,271,272,276,281,284,288,291,293,300,303,304,306,309,319,331,332,334,338,347,351,353,357,358,362,364,367,370,375,376,378,382,385,386,392,395,405,406,408,425,427,432,441,452,453,454,456,457,463,466,474,476,477,480,486,489,490,492,495,500,505,508,511,516,518,524,525,527,528,531,537,549,559,561,564,567,571,574,586,588,591,594,595,602,606,607,610,616,619,621,622,627,634,635,646,647,648,654,656,657,659,666,670,678,679,680,682,686,688,695,696,699,700,707,709,714,717,719,721,722,725,733,737,742,755,759,763,768,771,776,782,784,786,788,791,798,803,806,810,811,812,816,817,819,823,825,827,830,832,837,838,840,841,856,860,861,867,868,869,874,875,885,886,889,895,896,899,901,
# ...

# %%
print(df.isna().sum().sum())
print(df.duplicated().sum())
# Out:
# 709855
# 0

# %%
df.dropna(axis=1, inplace =True)

# %%
df.isna().sum().sum()
# Out:
# 1

# %%
df.replace('#NAME?',np.nan, inplace = True)

# %%
df.dropna(inplace = True)

# %%
df['Dignosis'] = 6
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
df.head()
# Out:
#    centroid_1000199  centroid_1002403  centroid_100337  centroid_1004450  \
# 0         -0.115418         -0.785949         0.379417         -1.286144
# 1          0.342361         -0.196726         0.756012         -0.399051
# 2         -0.228722         -0.695308         0.399504         -1.808431
# 3         -0.112457         -0.628286         0.365758         -0.695937
# 4          0.586698          0.018303         1.085691         -0.805421
#
#    centroid_1009647  centroid_101061  centroid_101144_s2  centroid_101298  \
# 0         -0.083105        -0.115418            0.042160         0.062469
# 1         -0.075704         0.300545            0.425803         0.640084
# 2         -0.172445        -0.154445           -0.007157         0.092119
# 3         -1.275962        -0.500196           -0.689596        -0.133281
# 4          0.166577         0.532730            0.636838         0.843652
#
#    centroid_101575  centroid_101899  ...  ETEC_3776  ETEC_3776_S1  \
# ...

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# (249, 50)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)

# %%
IGA = pd.DataFrame(X_selected)
IGA['Dignosis'] = 6
IGA.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.238799 -0.238799  -1.23448  0.423076 -0.021871  0.439851    0.2312
# 1 -1.064166  0.193308 -0.537809  0.732789  0.010318  0.778451  0.607761
# 2  -0.20957 -0.248288 -1.116933  0.381145  -0.54906  0.460435  0.271458
# 3 -1.122669 -0.202645 -0.734845  0.369576 -0.610604  0.199952  0.209359
# 4  0.188881   0.44338 -0.331722  1.044409   0.06221  1.040117  0.986067
#
#           7         8         9  ...        41        42        43        44  \
# 0  -0.00722 -0.021871 -0.238799  ...   -1.3403  0.759038  0.035279  0.174871
# 1  0.256354  0.159824  0.106866  ... -0.866072  0.951535  0.407348  0.193308
# 2 -0.037795 -0.352914 -0.136801  ... -0.829791  0.740303 -0.069564 -0.007157
# 3  0.272268 -0.112457  0.241437  ...  -1.21208   0.66887 -0.261455  0.312261
# 4  0.644855   0.44338   0.44338  ... -0.076947  1.234075  0.612216  0.421963
#
#          45        46        47        48        49 Dignosis
# ...

# %%
IGA.to_csv("IGA Dermatosis/Feature.csv", index=False)

# %%
gene = pd.concat([gene, IGA])
gene['Dignosis'].value_counts()
# Out:
# 6    249
# 0    120
# 2     68
# 5     57
# 1     48
# 4     48
# 3      8
# Name: Dignosis, dtype: int64

# %% [markdown]
# # Lichen Planus

# %%
df = pd.read_csv("Lichen Planus/Transform_Data.csv")

# %%
print(df.isna().sum().sum())
print(df.duplicated().sum())
# Out:
# 76
# 0

# %%
df.dropna(axis = 1, inplace = True)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['Dignosis'] = 7
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# (18, 50)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)

# %%
Lichen = pd.DataFrame(X_selected)
Lichen['Dignosis'] = 7
Lichen.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.849041  2.415472  2.216403  2.398253  1.873243  3.141241  3.148912
# 1  1.921477  2.406971  2.159406  2.437133  1.964118  3.019384  3.118415
# 2  1.932012  2.405342  1.791414  2.397434  2.369868  3.119064  3.213659
# 3  1.354375  2.255595  2.078081  2.312160  1.699219  3.139570  3.158159
# 4  1.693087  2.471533  2.149092  2.348398  2.026915  3.128719  3.268064
#
#           7         8         9  ...        41        42        43        44  \
# 0  1.863985  1.837309  3.034529  ...  1.773822  2.250881  2.240357  2.481352
# 1  2.121765  1.864721  3.018216  ...  1.679838  2.345660  2.259800  2.150632
# 2  2.188999  1.964169  2.976593  ...  1.860769  2.404544  2.344847  2.409937
# 3  1.787771  1.858148  2.981303  ...  1.928047  2.559537  2.429547  2.416927
# 4  2.309183  1.660909  2.947394  ...  1.966224  2.338702  2.457090  2.253398
#
#          45        46        47        48        49  Dignosis
# ...

# %%
Lichen.to_csv("Lichen Planus/Feature.csv", index=False)

# %%
gene = pd.concat([gene, Lichen])
gene['Dignosis'].value_counts()
# Out:
# 6    249
# 0    120
# 2     68
# 5     57
# 1     48
# 4     48
# 7     18
# 3      8
# Name: Dignosis, dtype: int64

# %% [markdown]
# # Lupus of the skin

# %%
df = pd.read_csv("Lupus of the skin/Transform_Data.csv")

# %%
print(df.isna().sum().sum())
print(df.duplicated().sum())
# Out:
# 102
# 0

# %%
df.dropna(axis = 1 , inplace = True)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['Dignosis'] = 8
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# (16, 50)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)

# %%
Lupus = pd.DataFrame(X_selected)
Lupus['Dignosis'] = 8
Lupus.head()
# Out:
#            0          1          2          3          4          5  \
# 0  16.538416  16.445257  16.543545  16.233788  16.488248  13.929166
# 1  11.830911  11.339850  11.383164  16.244773  12.289587  13.043540
# 2  16.077546  16.107769  16.340093  16.199011  16.473381  15.443526
# 3   9.604553   9.339850   9.605480  16.134797   9.888743   7.714246
# 4  10.511753  10.087463  10.014718  16.524083   9.764042   8.285402
#
#            6          7          8          9  ...         41         42  \
# 0  14.309441  14.352009  13.875173  13.566470  ...   9.113742   9.854089
# 1  12.518776  12.506803  13.357964  15.202908  ...   9.847840   9.737247
# 2  15.574165  15.480348  15.350698  14.653629  ...  10.473198  10.429407
# 3   7.499846   9.447083   8.912889   7.727920  ...   9.785452   9.938109
# 4   8.312883   8.204571   8.636625   8.312883  ...   9.079485   9.036174
#
#           43         44         45         46         47         48        49  \
# ...

# %%
Lupus.to_csv("Lupus of the skin/Feature.csv", index=False)

# %%
gene = pd.concat([gene, Lupus])
gene['Dignosis'].value_counts()
# Out:
# 6    249
# 0    120
# 2     68
# 5     57
# 1     48
# 4     48
# 7     18
# 8     16
# 3      8
# Name: Dignosis, dtype: int64

# %% [markdown]
# # Ocular Cicatrical pemphigoid

# %%
df = pd.read_csv("Ocular Cicatrical pemphigoid/Transform_Data.csv")

# %%
print(df.isna().sum().sum())
print(df.duplicated().sum())
# Out:
# 0
# 0

# %%
df['Dignosis'] = 9
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)
# (24, 50)

# %%
Ocular = pd.DataFrame(X_selected)
Ocular['Dignosis'] = 9
Ocular.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  5.779505  6.124448  5.920818  5.579267  5.725107  5.798849  5.686045
# 1  5.600778  6.003211  5.772516  5.609415  5.892571  5.737825  6.042828
# 2  5.801297  5.947003  5.918725  5.793240  5.857230  5.810800  5.828319
# 3  5.921213  6.096311  6.002665  5.692042  5.838357  5.882085  5.717328
# 4  5.935212  5.764976  6.031001  5.783292  6.019079  5.854730  5.617859
#
#           7         8         9  ...        41        42        43        44  \
# 0  6.073665  5.363891  6.007340  ...  5.936345  6.092714  5.585570  6.303434
# 1  6.050747  5.735662  5.797570  ...  6.021635  5.966813  5.634284  5.982539
# 2  5.990882  5.610350  5.902795  ...  5.780057  6.088018  5.981459  6.050053
# 3  6.243756  5.850550  5.740206  ...  6.091238  5.833069  5.875302  6.184245
# 4  5.934718  5.639482  5.867173  ...  6.304740  6.185994  5.853999  6.503668
#
#          45        46        47        48        49  Dignosis
# ...

# %%
Ocular.to_csv("Ocular Cicatrical pemphigoid/Feature.csv", index=False)

# %%
gene = pd.concat([gene, Ocular])
gene['Dignosis'].value_counts()
# Out:
# 6    249
# 0    120
# 2     68
# 5     57
# 1     48
# 4     48
# 9     24
# 7     18
# 8     16
# 3      8
# Name: Dignosis, dtype: int64

# %% [markdown]
# # vitiligo

# %%
df = pd.read_csv("vitiligo/Transform_Data.csv")

# %%
print(df.isna().sum().sum())
print(df.duplicated().sum())
# Out:
# 0
# 0

# %%
df['Dignosis'] = 10
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
# define feature selection
fs = SelectKBest(score_func=f_classif, k=key)
# apply feature selection
X_selected = fs.fit_transform(X, y)
print(X_selected.shape)
# Out:
# (8, 50)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\laptop\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py:110: RuntimeWarning: invalid value encountered in true_divide
#   msb = ssbn / float(dfbn)

# %%
vitiligo = pd.DataFrame(X_selected)
vitiligo['Dignosis'] = 10
vitiligo.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  3.080496  2.699829  2.762493  3.030042  2.908232  2.783767  2.603979
# 1  3.053410  2.670273  2.842796  3.092897  2.936981  2.931405  2.728937
# 2  3.131611  2.722569  2.811341  3.164199  2.940942  2.868363  2.688703
# 3  3.079195  2.681130  2.823215  3.114042  2.913594  2.924851  2.717170
# 4  3.147705  2.728937  2.852847  3.244738  2.981070  2.927757  2.711233
#
#           7         8         9  ...        41        42        43        44  \
# 0  2.628297  2.628297  2.918016  ...  2.718707  2.573881  2.636924  2.613567
# 1  2.673335  2.651962  3.091143  ...  3.007003  2.681130  2.808336  2.655350
# 2  2.651431  2.645558  3.100760  ...  2.940942  2.683128  2.812688  2.651431
# 3  2.667175  2.620584  3.086903  ...  3.022133  2.695389  2.809058  2.664040
# 4  2.644195  2.574936  3.043056  ...  2.903521  2.690415  2.839018  2.664040
#
#          45        46        47        48        49  Dignosis
# ...

# %%
vitiligo.to_csv("vitiligo/Feature.csv", index=False)

# %%
gene = pd.concat([gene, vitiligo])
gene['Dignosis'].value_counts()
# Out:
# 6     249
# 0     120
# 2      68
# 5      57
# 1      48
# 4      48
# 9      24
# 7      18
# 8      16
# 3       8
# 10      8
# Name: Dignosis, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from sklearn import tree
from sklearn.metrics import confusion_matrix

# %%
X = gene.iloc[:,:-1]
y = gene.iloc[:,-1:]

# %%
X_train , X_test ,y_train , y_test = train_test_split(
                                            X,y 
                                            ,test_size=0.60
                                            ,random_state=42,
                                             stratify=y)

# %%
tree_clf = DecisionTreeClassifier(max_depth=6)
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
y_pred = tree_clf.predict(X_test)

# %%
accuracy_score(y_pred , y_test)
# Out:
# 0.949874686716792

# %%
print (classification_report(y_pred, y_test, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.95833   0.98571   0.97183        70
#            1    1.00000   1.00000   1.00000        29
#            2    1.00000   1.00000   1.00000        41
#            3    1.00000   1.00000   1.00000         5
#            4    1.00000   0.90625   0.95082        32
#            5    1.00000   0.97143   0.98551        35
#            6    1.00000   1.00000   1.00000       150
#            7    0.00000   0.00000   0.00000         0
#            8    0.88889   1.00000   0.94118         8
#            9    1.00000   0.48276   0.65116        29
#           10    0.00000   0.00000   0.00000         0
#
#     accuracy                        0.94987       399
#    macro avg    0.80429   0.75874   0.77277       399
# weighted avg    0.99046   0.94987   0.96331       399
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rnd_clf = RandomForestClassifier(n_estimators=1000,
                                 max_depth= 6,
                                 random_state=42,
                                )

# %%
rnd_clf .fit(X_train , y_train)
# Out:
# C:\Users\laptop\AppData\Local\Temp/ipykernel_4624/4190684491.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnd_clf .fit(X_train , y_train)
# RandomForestClassifier(max_depth=6, n_estimators=1000, random_state=42)

# %%
y_pred_rnd1 = rnd_clf.predict(X_test)

# %%
accuracy_score (y_pred_rnd1, y_test)
# Out:
# 1.0

# %%
print (classification_report(y_pred_rnd1, y_test, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    1.00000   1.00000   1.00000        72
#            1    1.00000   1.00000   1.00000        29
#            2    1.00000   1.00000   1.00000        41
#            3    1.00000   1.00000   1.00000         5
#            4    1.00000   1.00000   1.00000        29
#            5    1.00000   1.00000   1.00000        34
#            6    1.00000   1.00000   1.00000       150
#            7    1.00000   1.00000   1.00000        11
#            8    1.00000   1.00000   1.00000         9
#            9    1.00000   1.00000   1.00000        14
#           10    1.00000   1.00000   1.00000         5
#
#     accuracy                        1.00000       399
#    macro avg    1.00000   1.00000   1.00000       399
# weighted avg    1.00000   1.00000   1.00000       399

# %%
import pickle
filename = 'Breast_caner_model.sav'
pickle.dump(model, open(filename, 'wb'))
