# %%
import pandas as pd

# %%
input_path = 'Data.csv'
output_path = 'Transform_Data.csv'

# %%
df = pd.read_csv('Data.csv')

# %%
df.head()
# Out:
#      Unnamed: 0  GSM5917081  GSM5917082  GSM5917083  GSM5917084  GSM5917085  \
# 0  ASCRP3000001    2.754771    2.662660    2.743855    2.711657    2.721054
# 1  ASCRP3000002    3.478207    3.391250    3.441500    3.383201    3.449090
# 2  ASCRP3000003    3.197430    3.251786    3.218639    3.251237    3.244738
# 3  ASCRP3000004    2.901669    2.709865    2.761449    2.711657    2.792737
# 4  ASCRP3000005    2.928064    2.831210    2.906128    2.848177    2.886409
#
#    GSM5917086  GSM5917087  GSM5917088
# 0    2.725773    2.671015    2.682317
# 1    3.390197    3.400217    3.370649
# 2    3.167238    3.347342    3.277187
# 3    2.682317    2.774226    2.700272
# 4    2.842796    2.890239    2.847751

# %%
df = df.T

# %%
b=df.iloc[0:1,0:]

# %%
col = b.iloc[0]

# %%
df
# Out:
#                    0             1             2             3      \
# Unnamed: 0  ASCRP3000001  ASCRP3000002  ASCRP3000003  ASCRP3000004
# GSM5917081      2.754771      3.478207       3.19743      2.901669
# GSM5917082       2.66266       3.39125      3.251786      2.709865
# GSM5917083      2.743855        3.4415      3.218639      2.761449
# GSM5917084      2.711657      3.383201      3.251237      2.711657
# GSM5917085      2.721054       3.44909      3.244738      2.792737
# GSM5917086      2.725773      3.390197      3.167238      2.682317
# GSM5917087      2.671015      3.400217      3.347342      2.774226
# GSM5917088      2.682317      3.370649      3.277187      2.700272
#
#                    4             5             6             7      \
# Unnamed: 0  ASCRP3000005  ASCRP3000006  ASCRP3000007  ASCRP3000008
# GSM5917081      2.928064      2.697507      3.140951      2.645558
# GSM5917082       2.83121      2.702445      3.066214      2.761449
# ...

# %%
df1 = pd.DataFrame(df)
df1.columns = col
df1.head()
# Out:
# Unnamed: 0  ASCRP3000001  ASCRP3000002  ASCRP3000003  ASCRP3000004  \
# Unnamed: 0  ASCRP3000001  ASCRP3000002  ASCRP3000003  ASCRP3000004
# GSM5917081      2.754771      3.478207       3.19743      2.901669
# GSM5917082       2.66266       3.39125      3.251786      2.709865
# GSM5917083      2.743855        3.4415      3.218639      2.761449
# GSM5917084      2.711657      3.383201      3.251237      2.711657
#
# Unnamed: 0  ASCRP3000005  ASCRP3000006  ASCRP3000007  ASCRP3000008  \
# Unnamed: 0  ASCRP3000005  ASCRP3000006  ASCRP3000007  ASCRP3000008
# GSM5917081      2.928064      2.697507      3.140951      2.645558
# GSM5917082       2.83121      2.702445      3.066214      2.761449
# GSM5917083      2.906128      2.623671      2.994559      2.766857
# GSM5917084      2.848177       2.69805      3.071335      2.746808
#
# Unnamed: 0  ASCRP3000009  ASCRP3000010  ...  ASCRP3013608  ASCRP3013609  \
# Unnamed: 0  ASCRP3000009  ASCRP3000010  ...  ASCRP3013608  ASCRP3013609
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, Unnamed: 0 to GSM5917088
# Columns: 13617 entries, ASCRP3000001 to ASCRP3013617
# dtypes: object(13617)
# memory usage: 957.8+ KB

# %%
dataFrame = df1.drop('Unnamed: 0')

# %%
dataFrame['Dignosis'] = 'vitiligo'

# %%
dataFrame
# Out:
# Unnamed: 0 ASCRP3000001 ASCRP3000002 ASCRP3000003 ASCRP3000004 ASCRP3000005  \
# GSM5917081     2.754771     3.478207      3.19743     2.901669     2.928064
# GSM5917082      2.66266      3.39125     3.251786     2.709865      2.83121
# GSM5917083     2.743855       3.4415     3.218639     2.761449     2.906128
# GSM5917084     2.711657     3.383201     3.251237     2.711657     2.848177
# GSM5917085     2.721054      3.44909     3.244738     2.792737     2.886409
# GSM5917086     2.725773     3.390197     3.167238     2.682317     2.842796
# GSM5917087     2.671015     3.400217     3.347342     2.774226     2.890239
# GSM5917088     2.682317     3.370649     3.277187     2.700272     2.847751
#
# Unnamed: 0 ASCRP3000006 ASCRP3000007 ASCRP3000008 ASCRP3000009 ASCRP3000010  \
# GSM5917081     2.697507     3.140951     2.645558     2.776282     3.032367
# GSM5917082     2.702445     3.066214     2.761449      2.66266      2.83206
# ...

# %%
dataFrame.to_csv(output_path, index=False)
